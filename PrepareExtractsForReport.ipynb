# %%
import utils    
import tabulate
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import pandas as pd
import numpy as np

import keras
import model01
import datasets
import metrics

# %%
df = utils.load_1minute_fx_bars('EURUSD', 2009)['2009-03-16'].head()
print tabulate.tabulate(df, headers=df.columns, tablefmt="pipe")
# Out:
# |                     |   open |   high |    low |   close |
# |:--------------------|-------:|-------:|-------:|--------:|
# | 2009-03-16 00:00:00 | 1.2895 | 1.2895 | 1.2895 |  1.2895 |
# | 2009-03-16 00:01:00 | 1.2896 | 1.2897 | 1.2895 |  1.2895 |
# | 2009-03-16 00:02:00 | 1.2896 | 1.2896 | 1.2895 |  1.2896 |
# | 2009-03-16 00:03:00 | 1.2895 | 1.2896 | 1.2894 |  1.2895 |
# | 2009-03-16 00:04:00 | 1.2895 | 1.2895 | 1.2894 |  1.2895 |

# %%
df = utils.load_1minute_fx_bars('USDJPY', 2009)['2009-03-16'].head()
print tabulate.tabulate(df, headers=df.columns, tablefmt="pipe")
# Out:
# |                     |   open |   high |   low |   close |
# |:--------------------|-------:|-------:|------:|--------:|
# | 2009-03-16 00:00:00 |  98.25 |  98.25 | 98.23 |   98.24 |
# | 2009-03-16 00:01:00 |  98.23 |  98.24 | 98.23 |   98.24 |
# | 2009-03-16 00:03:00 |  98.25 |  98.25 | 98.24 |   98.24 |
# | 2009-03-16 00:04:00 |  98.25 |  98.25 | 98.23 |   98.24 |
# | 2009-03-16 00:05:00 |  98.23 |  98.23 | 98.22 |   98.23 |

# %%
df = utils.load_1minute_fx_bars('XAUUSD', 2009)['2009-03-16'].head()
print tabulate.tabulate(df, headers=df.columns, tablefmt="pipe")
# Out:
# |                     |   open |   high |    low |   close |
# |:--------------------|-------:|-------:|-------:|--------:|
# | 2009-03-16 00:00:00 | 926.7  | 926.7  | 926.38 |  926.55 |
# | 2009-03-16 00:01:00 | 926.6  | 926.6  | 926.33 |  926.55 |
# | 2009-03-16 00:02:00 | 926.6  | 926.7  | 926.53 |  926.7  |
# | 2009-03-16 00:03:00 | 926.65 | 926.7  | 926.65 |  926.68 |
# | 2009-03-16 00:04:00 | 926.63 | 926.63 | 926.43 |  926.43 |

# %%
print tabulate.tabulate(df.head(), headers=df.columns, tablefmt="pipe")
# Out:
# |                     |   open |   high |    low |   close |
# |:--------------------|-------:|-------:|-------:|--------:|
# | 2009-03-16 00:00:00 | 926.7  | 926.7  | 926.38 |  926.55 |
# | 2009-03-16 00:01:00 | 926.6  | 926.6  | 926.33 |  926.55 |
# | 2009-03-16 00:02:00 | 926.6  | 926.7  | 926.53 |  926.7  |
# | 2009-03-16 00:03:00 | 926.65 | 926.7  | 926.65 |  926.68 |
# | 2009-03-16 00:04:00 | 926.63 | 926.63 | 926.43 |  926.43 |

# %% [markdown]
# |       timestamp     |   open |   high |    low |   close |   |       timestamp     |   open |   high |    low |   close |
# |:-------------------:|-------:|-------:|-------:|--------:|   |:-------------------:|-------:|-------:|-------:|--------:|
# | 2009-01-01 18:59:00 | 1.4005 | 1.4005 | 1.4005 |  1.4005 |   | 2009-01-01 18:59:00 | 1.4005 | 1.4005 | 1.4005 |  1.4005 |
# | 2009-01-01 19:00:00 | 1.4008 | 1.4008 | 1.4003 |  1.4004 |   | 2009-01-01 19:00:00 | 1.4008 | 1.4008 | 1.4003 |  1.4004 |
# | 2009-01-01 19:01:00 | 1.4005 | 1.4009 | 1.4005 |  1.4008 |   | 2009-01-01 19:01:00 | 1.4005 | 1.4009 | 1.4005 |  1.4008 |
# | 2009-01-01 19:02:00 | 1.4009 | 1.4011 | 1.4009 |  1.4011 |   | 2009-01-01 19:02:00 | 1.4009 | 1.4011 | 1.4009 |  1.4011 |
# | 2009-01-01 19:03:00 | 1.4009 | 1.4009 | 1.4005 |  1.4005 |   | 2009-01-01 19:03:00 | 1.4009 | 1.4009 | 1.4005 |  1.4005 |

# %%
df = utils.load_1minute_fx_bars('USDJPY', 2009)

# %%
df['2009-03-16'].plot()
plt.title("USD/JPY OHLC prices in 1 minute samples on 2009-03-16")

plt.savefig('reportresources/usdjpy-20090316.png')

# %%
df['2009-02']['close'].plot(style='.-', alpha=0.3)
plt.title("USD/JPY closing prices February 2009")

plt.savefig('reportresources/usdjpy-feb2009-closing.png')

# %%
df['2009-02-06 02:00':'2009-02-06 03:00'].plot(style='.-')
plt.title("USD/JPY OHLC 1-hour extract")

plt.savefig('reportresources/usdjpy-1-hour.png')

# %% [markdown]
# ![](reportresources/usdjpy2009-closingprice-20090316.png)
#
# |                     |   open |   high |    low |   close |
# |:--------------------|-------:|-------:|-------:|--------:|
# | 2009-03-16 00:00:00 | 1.2895 | 1.2895 | 1.2895 |  1.2895 |
# | 2009-03-16 00:01:00 | 1.2896 | 1.2897 | 1.2895 |  1.2895 |
# | 2009-03-16 00:02:00 | 1.2896 | 1.2896 | 1.2895 |  1.2896 |
# | 2009-03-16 00:03:00 | 1.2895 | 1.2896 | 1.2894 |  1.2895 |
# | 2009-03-16 00:04:00 | 1.2895 | 1.2895 | 1.2894 |  1.2895 |

# %%
df = utils.load_1minute_fx_bars('EURUSD', 2009)[['close']]
df['return'] = df['close'].pct_change()
print tabulate.tabulate(df['2009-03-16'].head(8), headers=df.columns, tablefmt="pipe")
eurusd_ret_desc = df['return'].describe()
eurusd_ret = df['return']
eurusd = df['close']
# Out:
# |                     |   close |       return |
# |:--------------------|--------:|-------------:|
# | 2009-03-16 00:00:00 |  1.2895 |  0           |
# | 2009-03-16 00:01:00 |  1.2895 |  0           |
# | 2009-03-16 00:02:00 |  1.2896 |  7.75494e-05 |
# | 2009-03-16 00:03:00 |  1.2895 | -7.75434e-05 |
# | 2009-03-16 00:04:00 |  1.2895 |  0           |
# | 2009-03-16 00:06:00 |  1.2894 | -7.75494e-05 |
# | 2009-03-16 00:07:00 |  1.2893 | -7.75555e-05 |
# | 2009-03-16 00:08:00 |  1.2891 | -0.000155123 |

# %%
df = utils.load_1minute_fx_bars('USDJPY', 2009)[['close']]
df['return'] = df['close'].pct_change()
print tabulate.tabulate(df['2009-03-16'].head(8), headers=df.columns, tablefmt="pipe")
usdjpy_ret_desc = df['return'].describe()
usdjpy_ret = df['return']
usdjpy = df['close']
# Out:
# |                     |   close |       return |
# |:--------------------|--------:|-------------:|
# | 2009-03-16 00:00:00 |   98.24 | -0.000203542 |
# | 2009-03-16 00:01:00 |   98.24 |  0           |
# | 2009-03-16 00:03:00 |   98.24 |  0           |
# | 2009-03-16 00:04:00 |   98.24 |  0           |
# | 2009-03-16 00:05:00 |   98.23 | -0.000101792 |
# | 2009-03-16 00:06:00 |   98.22 | -0.000101802 |
# | 2009-03-16 00:07:00 |   98.21 | -0.000101812 |
# | 2009-03-16 00:08:00 |   98.22 |  0.000101823 |

# %%
df = utils.load_1minute_fx_bars('XAUUSD', 2009)[['close']]
df['return'] = df['close'].pct_change()
print tabulate.tabulate(df['2009-03-16'].head(8), headers=df.columns, tablefmt="pipe")
xauusd_ret_desc = df['return'].describe()
xauusd_ret = df['return']
xauusd = df['close']
# Out:
# |                     |   close |       return |
# |:--------------------|--------:|-------------:|
# | 2009-03-16 00:00:00 |  926.55 | -0.000194231 |
# | 2009-03-16 00:01:00 |  926.55 |  0           |
# | 2009-03-16 00:02:00 |  926.7  |  0.000161891 |
# | 2009-03-16 00:03:00 |  926.68 | -2.1582e-05  |
# | 2009-03-16 00:04:00 |  926.43 | -0.00026978  |
# | 2009-03-16 00:05:00 |  926.48 |  5.39706e-05 |
# | 2009-03-16 00:07:00 |  926.45 | -3.23806e-05 |
# | 2009-03-16 00:08:00 |  926.4  | -5.39695e-05 |

# %%
df = pd.DataFrame({'eurusd':eurusd_ret_desc, 'usdjpy': usdjpy_ret_desc, 'xauusd':xauusd_ret_desc})
print tabulate.tabulate(df, headers=df.columns, tablefmt='pipe')
# Out:
# |       |           eurusd |           usdjpy |           xauusd |
# |:------|-----------------:|-----------------:|-----------------:|
# | count | 355879           | 343455           | 276108           |
# | mean  |      8.96979e-08 |      1.05664e-07 |      6.56347e-07 |
# | std   |      0.000229856 |      0.000254723 |      0.000341481 |
# | min   |     -0.00652985  |     -0.0139469   |     -0.0078104   |
# | 25%   |     -7.79636e-05 |     -0.000109637 |     -0.000126912 |
# | 50%   |      0           |      0           |      0           |
# | 75%   |      7.83638e-05 |      0.000109721 |      0.000129271 |
# | max   |      0.0175358   |      0.00661001  |      0.00942465  |

# %%
eurusd_ret.hist(bins=30, range=(-.002,.002),alpha=0.5, normed=True, label='EURUSD')
usdjpy_ret.hist(bins=30, range=(-.002,.002),alpha=0.5, normed=True, label='USDJPY')
xauusd_ret.hist(bins=30, range=(-.002,.002),alpha=0.5, normed=True, label='XAUUSD')

plt.title('histogram of closing price returns')
plt.legend()
plt.savefig('reportresources/histo_of_closing_price-returns.png')

# %%
fig, ax = plt.subplots(3,1, sharex=True)
eurusd.plot(ax=ax[0], label='EURUSD', style='b-')
usdjpy.plot(ax=ax[1], label='USDJPY', style='g-')
xauusd.plot(ax=ax[2], label='XAUUSD', style='r-')
ax[0].set_title('Closing Price')
ax[0].legend()
ax[1].legend()
ax[2].legend()

plt.savefig('reportresources/3-pairs-closing-price-subplots.png')

# %%
fig, ax = plt.subplots(3,1, sharex=True)
(eurusd_ret+1).cumprod().plot(ax=ax[0], label='EURUSD', style='b-')
(usdjpy_ret+1).cumprod().plot(ax=ax[1], label='USDJPY', style='g-')
(xauusd_ret+1).cumprod().plot(ax=ax[2], label='XAUUSD', style='r-')
ax[0].set_title('Cumulative product of (1+return)')
ax[0].legend()
ax[1].legend()
ax[2].legend()
plt.savefig('reportresources/3-pairs-cumprod-returns.png')

# %%
plt.figure()
(eurusd_ret+1).cumprod().plot(label='EURUSD')
(usdjpy_ret+1).cumprod().plot(label='USDJPY')
(xauusd_ret+1).cumprod().plot(label='XAUUSD')
plt.legend()

# %%
# !ls ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0*
# Out:
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-005-0.6940.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-010-0.6932.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-015-0.6931.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-020-0.6932.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-025-0.6931.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-030-0.6931.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-035-0.6932.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-040-0.6931.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-045-0.6932.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-050-0.6932.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-055-0.6932.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-060-0.6932.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-065-0.6933.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-070-0.6932.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-075-0.6933.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-080-0.6933.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-085-0.6933.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-090-0.6932.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-095-0.6933.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-100-0.6934.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-105-0.6933.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-110-0.6933.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-115-0.6934.hdf5
# ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0.npz

# %%
# load test dataset
lookahead=1
dataset = 'DS3'
window=25
sym='EURUSD'
year=2016
title = sym + " " + str(year)
X_test, Y_test, prices_test = datasets.load(datasets.filename(dataset, lookahead, window, sym, year))

# %% [markdown]
# #### 100x100x100 Network with Dropout = 0.0

# %%
pc = model01.ProgressCallback.load('MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0')

model_desc = "MLP: 100x100x100 dropout=0"
model_caption = "training set: EURUSD 2009-2014, validation set: EURUSD 2015"
#ylims = (0.692,0.695)
ylims = (0.686,0.695)


#FILENAME = './output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-115-0.6934.hdf5'
FILENAME = './output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0-020-0.6932.hdf5'
model = keras.models.load_model(FILENAME)
# Out:
# loading from file: ./output/MLPModel01_20170418_1912_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0.npz

# %%
fig = plt.figure()
plt.plot(pc.train_losses[:], label='training set')
plt.plot(pc.validation_losses[:], label='validation set')
ax= fig.axes[0]
ax.set_ylim(ylims[0], ylims[1])
ax.set_xlabel('epoch')
ax.set_ylabel('binary cross-entropy loss')
plt.title('training curve - ' + model_desc)
plt.legend()

# %%
# Model performance report
Y_test_pred = model.predict(X_test.as_matrix(), batch_size=1024)
metrics.performance_report(title,  prices_test,  lookahead, Y_test, Y_test_pred, cum_return_plot=True, histogram=True, heatmap=True)
# Out:
# EURUSD 2016: f1-score: 0.517, mean future return: 0.023 bps, annualized future return 1.369
# [[94335 77531]
#  [88760 83801]]

# %% [markdown]
# #### 100x100x100 Network with Dropout = 0.5

# %%
pc = model01.ProgressCallback.load('MLPModel01_20170418_1151_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0.5')

model_desc = "MLP: 100x100x100 dropout=0.5"
model_caption = "training set: EURUSD 2009-2014, validation set: EURUSD 2015"
ylims = (0.689,0.693 )

FILENAME = './output/MLPModel01_20170418_1151_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0.5-1005-0.6913.hdf5'
model = keras.models.load_model(FILENAME)
# Out:
# loading from file: ./output/MLPModel01_20170418_1151_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0.5.npz
# WARNING: run-id doesn't match: MLPModel01_20170418_1151_EURUSD_DS3_20092014_LA1_F99_C2_L100_100_100_DO0.5 != MLPModel01_20170418_1151_LA1_F99_C2_L100_100_100_DO0.5

# %%
fig = plt.figure()
plt.plot(pc.train_losses[:], label='training set')
plt.plot(pc.validation_losses[:], label='validation set')
ax= fig.axes[0]
ax.set_ylim(ylims[0], ylims[1])
ax.set_xlabel('epoch')
ax.set_ylabel('binary cross-entropy loss')
plt.title('training curve - ' + model_desc)
plt.legend()

# %%
# Model performance report
Y_test_pred = model.predict(X_test.as_matrix(), batch_size=1024)
metrics.performance_report(title,  prices_test,  lookahead, Y_test, Y_test_pred, cum_return_plot=True, histogram=True, heatmap=True)
# Out:
# EURUSD 2016: f1-score: 0.519, mean future return: 0.024 bps, annualized future return 1.475
# [[82352 89514]
#  [75875 96686]]
